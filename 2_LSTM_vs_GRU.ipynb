# %% [markdown]
# ### **LSTM VS GRU (WITH 25 EPOCHS AND 320 BATCH)**
# -BASE MODELS to later adjust parameters in following notebooks

# %% [markdown]
# ### Import Required Libraries

# %%
import string
import re
from numpy import array, argmax, random, take
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding, Bidirectional, RepeatVector, TimeDistributed, GRU
from keras.preprocessing.text import Tokenizer
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from keras import optimizers
import matplotlib.pyplot as plt
% matplotlib inline
pd.set_option('display.max_colwidth', 200)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Read Data

# %% [markdown]
# Our data is a text file of English-Spanish sentence pairs. First we will read the file using the function defined below.

# %%
# function to read raw text file
def read_text(filename):
    # open the file
    file = open(filename, mode='rt', encoding='utf-8')
    # read all text
    text = file.read()
    file.close()
    return text

# %% [markdown]
# Now let's define a function to split the text into English-Spanish pairs separated by '\n' and then split these pairs into English sentences and Spanish sentences.

# %%
# split a text into sentences
def to_lines(text):
    sents = text.strip().split('\n')
    sents = [i.split('\t') for i in sents]
    return sents

# %% [markdown]
# Mount your drive:

# %%
from google.colab import drive
drive.mount('/content/drive')

# Navigate to code directory
# %cd /content/drive/My Drive/NLP_Julia
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive/NLP_Julia

# %%
data = read_text("spa-eng/spa.txt")
spa_eng = to_lines(data)
spa_eng = array(spa_eng)[:,0:2] #NOS QUEDAMOS SOLO CON LAS PRIMERAS COLUMNAS QUE TIENEN LA INFORMACION

# %% [markdown]
# The actual data contains over 150,000 sentence-pairs. However, we will use the first 50,000 sentence pairs only to reduce the training time of the model. You can change this number as per you system computation power.

# %%
spa_eng = spa_eng[:50000,:]

# %% [markdown]
# ### Text Pre-Processing

# %% [markdown]
# #### Text Cleaning
#
# Let's take a look at our data, then we will decide which pre-processing steps to adopt.

# %%
spa_eng
# Out:
# array([['Go.', 'Ve.'],
#        ['Go.', 'Vete.'],
#        ['Go.', 'Vaya.'],
#        ...,
#        ['I am waiting for my driver.', 'Estoy esperando a mi chofer.'],
#        ['I appreciate all your help.', 'Aprecio toda tu ayuda.'],
#        ['I appreciate your interest.', 'Agradezco tu interés.']],
#       dtype='<U332')

# %% [markdown]
# We will get rid of the punctuation marks, and then convert the text to lower case.

# %% [markdown]
# #### *IMPORTANTE QUITAR LA EXCLAMACION HACIA ARRIBA PARA EL ESPAÑOL

# %%
# Remove punctuation
spa_eng[:,0] = [s.translate(str.maketrans('', '', string.punctuation)) for s in spa_eng[:,0]]
spa_eng[:,1] = [s.translate(str.maketrans('', '', string.punctuation)) for s in spa_eng[:,1]]

## TAMBIEN QUITAMOS ESTA EXCLAMACION QUE LO ANTERIOR NO LO QUITA
spa_eng[:,0] = [s.translate(str.maketrans('', '', '¡')) for s in spa_eng[:,0]]
spa_eng[:,1] = [s.translate(str.maketrans('', '', '¡')) for s in spa_eng[:,1]]

# convert to lowercase
for i in range(len(spa_eng)):
    spa_eng[i,0] = spa_eng[i,0].lower()
    
    spa_eng[i,1] = spa_eng[i,1].lower()

# %%
spa_eng
# Out:
# array([['go', 've'],
#        ['go', 'vete'],
#        ['go', 'vaya'],
#        ...,
#        ['i am waiting for my driver', 'estoy esperando a mi chofer'],
#        ['i appreciate all your help', 'aprecio toda tu ayuda'],
#        ['i appreciate your interest', 'agradezco tu interés']],
#       dtype='<U332')

# %% [markdown]
# #### Text to Sequence Conversion
#
# To feed our data in a Seq2Seq model, we will have to convert both the input and the output sentences into integer sequences of fixed length. Before that, let's visualise the length of the sentences. We will capture the lengths of all the sentences in two separate lists for English and Spanish, respectively.

# %%
# empty lists
eng_l = []
spa_l = []

# populate the lists with sentence lengths
for i in spa_eng[:,0]:
    eng_l.append(len(i.split()))

for i in spa_eng[:,1]:
    spa_l.append(len(i.split()))

# %%
length_df = pd.DataFrame({'eng':eng_l, 'spa':spa_l})
print(length_df)
print(max(length_df.eng))
print(max(length_df.spa))
# Out:
#        eng  spa
# 0        1    1
# 1        1    1
# 2        1    1
# 3        1    1
# 4        1    1
# ...    ...  ...
# 49995    6    5
# 49996    8    6
# 49997    6    5
# 49998    5    4
# 49999    4    3
#
# [50000 rows x 2 columns]
# 8
# 12

# %%
length_df.hist(bins = 30)
plt.show()

# %% [markdown]
# The maximum length of the Spanish sentences is 12 and that of the English phrases is 8.

# %% [markdown]
# Let's vectorize our text data by using Keras's Tokenizer() class. It will turn our sentences into sequences of integers. Then we will pad those sequences with zeros to make all the sequences of same length.

# %%
# function to build a tokenizer
def tokenization(lines):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(lines)
    return tokenizer

# %%
# prepare english tokenizer
eng_tokenizer = tokenization(spa_eng[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1

eng_length = 8
print('English Vocabulary Size: %d' % eng_vocab_size)
# Out:
# English Vocabulary Size: 6942

# %%
# prepare Spanish tokenizer
spa_tokenizer = tokenization(spa_eng[:, 1])
spa_vocab_size = len(spa_tokenizer.word_index) + 1

spa_length = 8
print('Spanish Vocabulary Size: %d' % spa_vocab_size)
# Out:
# Spanish Vocabulary Size: 13937

# %%
print(spa_tokenizer.word_counts)
# Out:
# OrderedDict([('ve', 118), ('vete', 42), ('vaya', 46), ('váyase', 7), ('hola', 21), ('corre', 19), ('corran', 2), ('corra', 1), ('corred', 2), ('¿quién', 380), ('órale', 10), ('fuego', 37), ('incendio', 5), ('disparad', 3), ('ayuda', 184), ('socorro', 2), ('auxilio', 3), ('salta', 4), ('salte', 2), ('parad', 2), ('para', 547), ('pare', 6), ('espera', 65), ('esperen', 10), ('continúa', 15), ('continúe', 7), ('corrí', 13), ('corría', 4), ('lo', 2126), ('intento', 8), ('he', 428), ('ganado', 16), ('oh', 8), ('no', 5964), ('tomátelo', 2), ('con', 871), ('soda', 3), ('disparen', 1), ('dispara', 1), ('dispará', 1), ('dispare', 3), ('sonríe', 5), ('al', 576), ('ataque', 6), ('atacad', 1), ('ataquen', 1), ('ataca', 1), ('levanta', 23), ('ahora', 489), ('mismo', 129), ('id', 6), ('vayan', 11), ('ya', 340), ('tengo', 878), ('¿lo', 63), ('pillas', 1), ('¿entendiste', 2), ('él', 2564), ('corrió', 23), ('métete', 5), ('adentro', 26), ('abrázame', 1), ('me', 3040), ('caí', 6), ('yo', 1183), ('sé', 431), ('salí', 12), ('mentí', 7), ('perdí', 62), ('dimito', 2), ('renuncié', 7), ('canté', 3), ('estoy', 1227), ('trabajando', 32), ('diecinueve', 2), ('levantado', 11), ('escucha', 30), ('escuche', 6), ('escuchen', 3), ('puede', 434), ('ser', 321), ('de', 4005), ('ninguna', 42), ('manera', 40), ('imposible', 17), ('ningún', 54), ('modo', 9), ('eso', 1146), ('nada', 364), ('ni', 82), ('cagando', 3), ('mangos', 2), ('minga', 1), ('en', 2050), ('pedo', 2), ('¿en', 53), ('serio', 43), ('¿la', 18), ('verdad', 209), ('gracias', 107), ('pruébalo', 2), ('procuramos', 1), ('ganamos', 8), ('¿por', 517), ('qué', 1019), ('pregúntale', 18), ('a', 5039), ('tom', 6787), ('mantente', 25), ('calma', 18), ('estate', 10), ('tranquilo', 13), ('justo', 50), ('bueno', 138), ('buena', 146), ('sed', 27), ('buenas', 30), ('buenos', 26), ('sea', 73), ('sean', 8), ('gentiles', 1), ('agradable', 31), ('pírate', 1), ('llamame', 2), ('llamadme', 1), ('llámame', 19), ('llámanos', 1), ('entre', 22), ('pase', 5), ('entren', 4), ('ándale', 1), ('suéltalo', 2), ('agarra', 6), ('bájate', 2), ('sal', 45), ('salid', 6), ('salgan', 4), ('aquí', 906), ('lárgate', 6), ('salga', 7), ('largo', 40), ('la', 3732), ('calle', 24), ('lárguese', 1), ('casa', 573), ('despacio', 34), ('hasta', 103), ('luego', 26), ('vista', 26), ('chau', 1), ('un', 3364), ('momento', 80), ('segundo', 31), ('fuertemente', 5), ('vino', 137), ('renunció', 12), ('ayúdame', 19), ('échame', 1), ('una', 1852), ('mano', 90), ('ayudame', 2), ('ayúdanos', 3), ('golpea', 2), ('sostenlo', 2), ('sostenedlo', 1), ('sosténgalo', 1), ('sosténganlo', 1), ('sosténganla', 1), ('sosténgala', 1), ('sostenla', 1), ('sostenedla', 1), ('resista', 1), ('resiste', 2), ('abraza', 2), ('acuerdo', 111), ('incliné', 2), ('mudado', 1), ('mudé', 3), ('trasladé', 1), ('trasladado', 1), ('dormí', 19), ('intenté', 16), ('iré', 33), ('soy', 597), ('gordo', 27), ('gorda', 12), ('forma', 20), ('afectado', 1), ('viejo', 65), ('tímido', 22), ('mojada', 4), ('está', 2279), ('bien', 527), ('únete', 1), ('nosotros', 185), ('parte', 54), ('nuestra', 52), ('guárdalo', 1), ('también', 137), ('abre', 27), ('perfecto', 41), ('empújala', 1), ('empújalo', 1), ('empújadlo', 1), ('empújadla', 1), ('empújelo', 1), ('empújela', 1), ('empújenlo', 1), ('empújenla', 1), ('nos', 439), ('vemos', 19), ('muéstramelo', 1), ('enséñamelo', 2), ('mostrame', 5), ('cierra', 37), ('boca', 47), ('cerrá', 5), ('el', 3423), ('pico', 3), ('sáltatelo', 1), ('páralo', 2), ('detenlo', 1), ('cógelo', 3), ('decime', 5), ('comió', 46), ('ganó', 38), ('espérame', 2), ('despierto', 34), ('despierta', 11), ('despiértate', 2), ('despertate', 1), ('lávate', 9), ('las', 955), ('manos', 65), ('preocupamos', 1), ('sabemos', 22), ('perdimos', 11), ('bienvenidos', 3), ('bienvenidas', 2), ('ha', 454), ('has', 158), ('¿estoy', 18), ('preguntales', 1), ('pregúntales', 1), ('aparta', 1), ('apártate', 2), ('hombre', 170), ('fuerte', 69), ('breve', 16), ('breves', 2), ('quieto', 17), ('te', 1317), ('muevas ...

# %% [markdown]
# Given below is a function to prepare the sequences. It will also perform sequence padding to a maximum sentence length as mentioned above.

# %%
# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
    # integer encode sequences
    seq = tokenizer.texts_to_sequences(lines)
    # pad sequences with 0 values
    seq = pad_sequences(seq, maxlen=length, padding='post')
    print(seq)
    print(len(seq))
    return seq

# %% [markdown]
# ### Model Building

# %% [markdown]
# We will now split the data into train and test set for model training and evaluation, respectively.

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(spa_eng, test_size=0.2, random_state = 12)

# %% [markdown]
# It's time to encode the sentences. We will encode Spanish sentences as the input sequences and English sentences as the target sequences. It will be done for both train and test datasets.

# %%
# prepare training data
trainX = encode_sequences(spa_tokenizer, spa_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
# Out:
# [[   1   10 1574 ...    0    0    0]
#  [4805    4    6 ...    0    0    0]
#  [  14 4930    0 ...    0    0    0]
#  ...
#  [  43  198 1663 ...    0    0    0]
#  [  18   12   15 ...    8 1195    0]
#  [   2  241 1477 ...    0    0    0]]
# 40000
# [[   3  182   10 ...    0    0    0]
#  [   1 1094    6 ...    0    0    0]
#  [  50  101    9 ...    0    0    0]
#  ...
#  [  44  444  432 ...    0    0    0]
#  [  22    4  123 ...  213    0    0]
#  [   1  202 2244 ...    0    0    0]]
# 40000

# %%
print(trainX.shape)
print(trainY.shape)
# Out:
# (40000, 8)
# (40000, 8)

# %%
# prepare validation data
testX = encode_sequences(spa_tokenizer, spa_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
# Out:
# [[  53   43   30 ...    0    0    0]
#  [ 235    4    1 ...    0    0    0]
#  [ 107 8429    0 ...    0    0    0]
#  ...
#  [9404  115  975 ...    0    0    0]
#  [1347   55  598 ...    0    0    0]
#  [   2   32 6681 ...    0    0    0]]
# 10000
# [[  36   16   40 ...    0    0    0]
#  [   1   37    3 ...    0    0    0]
#  [   2   99 1339 ...    0    0    0]
#  ...
#  [  56 1781   29 ...    0    0    0]
#  [  33    2  217 ...    0    0    0]
#  [   1  867   42 ...    0    0    0]]
# 10000

# %%
print(testX.shape)
print(testY.shape)
# Out:
# (10000, 8)
# (10000, 8)

# %% [markdown]
# Now comes the exciting part! Let us define our Seq2Seq model architecture. We are using an Embedding layer and an LSTM layer as our encoder and another LSTM layer followed by a Dense layer as the decoder.

# %%
# build NMT model (LSTM)
def build_model(in_vocab, out_vocab, in_timesteps, out_timesteps, units):
    model = Sequential()
    model.add(Embedding(in_vocab, units, input_length=in_timesteps, mask_zero=True))
    model.add(LSTM(units))
    model.add(RepeatVector(out_timesteps))    
    model.add(LSTM(units, return_sequences=True))
    model.add(Dense(out_vocab, activation='softmax'))
    return model

# %% [markdown]
# We are using RMSprop optimizer in this model as it is usually a good choice for recurrent neural networks.

# %%
print(spa_vocab_size)
print(eng_vocab_size)
print(spa_length)
print(eng_length)
# Out:
# 13937
# 6942
# 8
# 8

# %%
model = build_model(spa_vocab_size, eng_vocab_size, spa_length, eng_length, 512)
rms = optimizers.RMSprop(lr=0.001)
model.compile(optimizer=rms, loss='sparse_categorical_crossentropy')

# %% [markdown]
# Please note that we have used __'sparse_categorical_crossentropy'__ as the loss function because it allows us to use the target sequence as it is instead of one hot encoded format. One hot encoding the target sequences with such a huge vocabulary might consume our system's entire memory.

# %% [markdown]
# It seems we are all set to start training our model. We will train it for 25 epochs and with a batch size of 320. You may change and play these hyperparameters. We will also be using __ModelCheckpoint()__ to save the best model with lowest validation loss. I personally prefer this method over early stopping.

# %%
filename = 'modelLSTM.h1'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

history = model.fit(trainX, trainY.reshape(trainY.shape[0], trainY.shape[1], 1), 
          epochs=25, batch_size=320, #512 
          validation_split = 0.2,
          callbacks=[checkpoint], verbose=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 32000 samples, validate on 8000 samples
# Epoch 1/25
# 32000/32000 [==============================] - 10s 308us/step - loss: 3.6953 - val_loss: 3.2490
#
# Epoch 00001: val_loss improved from inf to 3.24898, saving model to model.h1.24_jan_19
# Epoch 2/25
# 32000/32000 [==============================] - 8s 235us/step - loss: 3.1257 - val_loss: 3.0652
#
# Epoch 00002: val_loss improved from 3.24898 to 3.06519, saving model to model.h1.24_jan_19
# Epoch 3/25
# 32000/32000 [==============================] - 7s 230us/step - loss: 2.9402 - val_loss: 2.9159
#
# Epoch 00003: val_loss improved from 3.06519 to 2.91594, saving model to model.h1.24_jan_19
# Epoch 4/25
# 32000/32000 [==============================] - 7s 233us/step - loss: 2.7321 - val_loss: 2.7263
#
# Epoch 00004: val_loss improved from 2.91594 to 2.72629, saving model to model.h1.24_jan_19
# Epoch 5/25
# 32000/32000 [==============================] - 8s 235us/step - loss: 2.5188 - val_loss: 2.5778
#
# Epoch 00005: val_loss improved from 2.72629 to 2.57780, saving model to model.h1.24_jan_19
# Epoch 6/25
# 32000/32000 [==============================] - 7s 234us/step - loss: 2.3295 - val_loss: 2.4486
#
# Epoch 00006: val_loss improved from 2.57780 to 2.44861, saving model to model.h1.24_jan_19
# Epoch 7/25
# 32000/32000 [==============================] - 7s 228us/step - loss: 2.1650 - val_loss: 2.3298
#
# Epoch 00007: val_loss improved from 2.44861 to 2.32978, saving model to model.h1.24_jan_19
# Epoch 8/25
# 32000/32000 [==============================] - 7s 229us/step - loss: 2.0199 - val_loss: 2.2521
#
# Epoch 00008: val_loss improved from 2.32978 to 2.25206, saving model to model.h1.24_jan_19
# Epoch 9/25
# 32000/32000 [==============================] - 7s 233us/step - loss: 1.8839 - val_loss: 2.1791
#
# Epoch 00009: val_loss improved from 2.25206 to 2.17907, saving model to model.h1.24_jan_19
# Epoch 10/25
# 32000/32000 [==============================] - 7s 231us/step - loss: 1.7574 - val_loss: 2.1002
#
# Epoch 00010: val_loss improved from 2.17907 to 2.10021, saving model to model.h1.24_jan_19
# Epoch 11/25
# 32000/32000 [==============================] - 8s 236us/step - loss: 1.6374 - val_loss: 2.0535
#
# Epoch 00011: val_loss improved from 2.10021 to 2.05354, saving model to model.h1.24_jan_19
# Epoch 12/25
# 32000/32000 [==============================] - 7s 229us/step - loss: 1.5269 - val_loss: 1.9846
#
# Epoch 00012: val_loss improved from 2.05354 to 1.98460, saving model to model.h1.24_jan_19
# Epoch 13/25
# 32000/32000 [==============================] - 7s 229us/step - loss: 1.4209 - val_loss: 1.9454
#
# Epoch 00013: val_loss improved from 1.98460 to 1.94536, saving model to model.h1.24_jan_19
# Epoch 14/25
# 32000/32000 [==============================] - 7s 227us/step - loss: 1.3178 - val_loss: 1.9062
#
# Epoch 00014: val_loss improved from 1.94536 to 1.90620, saving model to model.h1.24_jan_19
# Epoch 15/25
# 32000/32000 [==============================] - 7s 232us/step - loss: 1.2229 - val_loss: 1.8711
#
# Epoch 00015: val_loss improved from 1.90620 to 1.87108, saving model to model.h1.24_jan_19
# Epoch 16/25
# 32000/32000 [==============================] - 7s 233us/step - loss: 1.1313 - val_loss: 1.8380
#
# Epoch 00016: val_loss improved from 1.87108 to 1.83803, saving model to model.h1.24_jan_19
# Epoch 17/25
# 32000/32000 [==============================] - 7s 231us/step - loss: 1.0456 - val_loss: 1.8355
#
# Epoch 00017: val_loss improved from 1.83803 to 1.83555, saving model to model.h1.24_jan_19
# Epoch 18/25
# 32000/32000 [==============================] - 7s 233us/step - loss: 0.9653 - val_loss: 1.7987
#
# Epoch 00018: val_loss improved from 1.83555 to 1.79875, saving model to model.h1.24_jan_19
# Epoch 19/25
# 32000/32000 [==============================] - 7s 233us/step - loss: 0.8901 - val_loss: 1.7766
#
# Epoch 00019: val_loss improved from 1.79875 to 1.77662, saving model to model.h1.24_jan_19
# Epoch 20/25
# 32000/32000 [==============================] - 7s 231us/step - loss: 0.8173 - val_loss: 1.7754
#
# Epoch 00020: val_loss improved from 1.77662 to 1.77537, saving model to model.h1.24_jan_19
# Epoch 21/25
# 32000/32000 [==============================] - 7s 234us/step - loss: 0.7490 - val_loss: 1.7578
#
# Epoch 00021: val_loss improved from 1.77537 to 1.75777, saving model to model.h1.24_jan_19
# Epoch 22/25
# 32000/32000 [==============================] - 7s 233us/step - loss: 0.6835 - val_loss: 1.7467
#
# Epoch 00022: val_loss improved from 1.75777 to 1.74669, saving model to model.h1.24_jan_19
# Epoch 23/25
# 32000/32000 [==============================] - 8s 242us/step - loss: 0.6234 - val_loss: 1.7390
#
# Epoch 00023: val_loss improved from 1.74669 to 1.73903, saving model to model.h1.24_jan_19
# Epoch 24/25
# 32000/32000 [==============================] - 7s 229us/step - loss: 0.5675 - val_loss: 1.7590
#
# Epoch 00024: val_loss did not improve from 1.73903
# Epoch 25/25
# 32000/32000 [==============================] - 7s 231us/step - loss: 0.5146 - val_loss: 1.7798
#
# Epoch 00025: val_loss did not improve from 1.73903

# %% [markdown]
# Let's compare the training loss and the validation loss.

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train','validation'])
plt.show()

# %% [markdown]
# ### Make Predictions

# %% [markdown]
# Let's load the saved model to make predictions.

# %%
model = load_model('modelLSTM.h1')
preds = model.predict_classes(testX.reshape((testX.shape[0],testX.shape[1])))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
def get_word(n, tokenizer):
    for word, index in tokenizer.word_index.items():
        if index == n:
            return word
    return None

# %%
# convert predictions into text (English)
preds_text = []
for i in preds:
    temp = []
    for j in range(len(i)):
        t = get_word(i[j], eng_tokenizer)
        if j > 0:
            if (t == get_word(i[j-1], eng_tokenizer)) or (t == None):
                temp.append('')
            else:
                temp.append(t)
             
        else:
            if(t == None):
                temp.append('')
            else:
                temp.append(t)            
        
    preds_text.append(' '.join(temp))

# %%
pred_df = pd.DataFrame({'Spanish':  test[:,1], 'actual traduction' : test[:,0], 'predicted' : preds_text})

# %%
pd.set_option('display.max_colwidth', 200)

# %%
pred_df.head(15)
# Out:
#                        Spanish  ...                     predicted
# 0     ellos son muy optimistas  ...             theyre very
# 1                conozco a tom  ...               i know tom
# 2               puedes negarte  ...              you may put
# 3               eso es privado  ...        thats is nonsense
# 4   tom saltó desde su asiento  ...     tom removed his  teeth
# 5   ¿jamás has vendido un auto  ...        have you ever a car
# 6        ¿cuántos hijos tienes  ...  how many books do you have
# 7         no te dejaré hacerlo  ...            i will  it do it
# 8               ¿no es hermoso  ...          is it beautiful
# 9           mi loro murió ayer  ...       my mother died back
# 10            comí una manzana  ...          i drank an apple
# 11           tom está contento  ...             tom is happy
# 12            cubre mi espalda  ...                 my back
# 13          tom está escondido  ...            tom is hiding
# 14                póngalo allí  ...             put it there
#
# [15 rows x 3 columns]

# %% [markdown]
# Taking into account that this is the first mode we ran, our results are surprisingly good. We will try other models.

# %% [markdown]
# ## **NOW WE TRY A GRU TO COMPARE:**

# %%
# build NMT model (GRU)
def build_model(in_vocab, out_vocab, in_timesteps, out_timesteps, units):
    model = Sequential()
    model.add(Embedding(in_vocab, units, input_length=in_timesteps, mask_zero=True))
    model.add(GRU(units))
    model.add(RepeatVector(out_timesteps))    
    model.add(GRU(units, return_sequences=True))
    model.add(Dense(out_vocab, activation='softmax'))
    return model
    

model2 = build_model(spa_vocab_size, eng_vocab_size, spa_length, eng_length, 512)
rms = optimizers.RMSprop(lr=0.001)
model2.compile(optimizer=rms, loss='sparse_categorical_crossentropy')

# %%
filename = 'modelGRU.h1'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

history = model2.fit(trainX, trainY.reshape(trainY.shape[0], trainY.shape[1], 1), 
          epochs=25, batch_size=320, #512 
          validation_split = 0.2,
          callbacks=[checkpoint], verbose=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 32000 samples, validate on 8000 samples
# Epoch 1/25
# 32000/32000 [==============================] - 8s 257us/step - loss: 3.6985 - val_loss: 3.2613
#
# Epoch 00001: val_loss improved from inf to 3.26134, saving model to modelGRU.h1
# Epoch 2/25
# 32000/32000 [==============================] - 8s 237us/step - loss: 3.1284 - val_loss: 3.0792
#
# Epoch 00002: val_loss improved from 3.26134 to 3.07918, saving model to modelGRU.h1
# Epoch 3/25
# 32000/32000 [==============================] - 8s 236us/step - loss: 2.9322 - val_loss: 2.9041
#
# Epoch 00003: val_loss improved from 3.07918 to 2.90409, saving model to modelGRU.h1
# Epoch 4/25
# 32000/32000 [==============================] - 8s 235us/step - loss: 2.7053 - val_loss: 2.6932
#
# Epoch 00004: val_loss improved from 2.90409 to 2.69323, saving model to modelGRU.h1
# Epoch 5/25
# 32000/32000 [==============================] - 8s 238us/step - loss: 2.4870 - val_loss: 2.5736
#
# Epoch 00005: val_loss improved from 2.69323 to 2.57360, saving model to modelGRU.h1
# Epoch 6/25
# 32000/32000 [==============================] - 8s 235us/step - loss: 2.3061 - val_loss: 2.4184
#
# Epoch 00006: val_loss improved from 2.57360 to 2.41842, saving model to modelGRU.h1
# Epoch 7/25
# 32000/32000 [==============================] - 8s 238us/step - loss: 2.1436 - val_loss: 2.3205
#
# Epoch 00007: val_loss improved from 2.41842 to 2.32052, saving model to modelGRU.h1
# Epoch 8/25
# 32000/32000 [==============================] - 8s 236us/step - loss: 1.9946 - val_loss: 2.2272
#
# Epoch 00008: val_loss improved from 2.32052 to 2.22718, saving model to modelGRU.h1
# Epoch 9/25
# 32000/32000 [==============================] - 7s 233us/step - loss: 1.8575 - val_loss: 2.1430
#
# Epoch 00009: val_loss improved from 2.22718 to 2.14299, saving model to modelGRU.h1
# Epoch 10/25
# 32000/32000 [==============================] - 8s 235us/step - loss: 1.7304 - val_loss: 2.0718
#
# Epoch 00010: val_loss improved from 2.14299 to 2.07176, saving model to modelGRU.h1
# Epoch 11/25
# 32000/32000 [==============================] - 8s 238us/step - loss: 1.6118 - val_loss: 2.0231
#
# Epoch 00011: val_loss improved from 2.07176 to 2.02311, saving model to modelGRU.h1
# Epoch 12/25
# 32000/32000 [==============================] - 8s 243us/step - loss: 1.4971 - val_loss: 1.9697
#
# Epoch 00012: val_loss improved from 2.02311 to 1.96965, saving model to modelGRU.h1
# Epoch 13/25
# 32000/32000 [==============================] - 8s 242us/step - loss: 1.3911 - val_loss: 1.9146
#
# Epoch 00013: val_loss improved from 1.96965 to 1.91458, saving model to modelGRU.h1
# Epoch 14/25
# 32000/32000 [==============================] - 7s 233us/step - loss: 1.2913 - val_loss: 1.8966
#
# Epoch 00014: val_loss improved from 1.91458 to 1.89656, saving model to modelGRU.h1
# Epoch 15/25
# 32000/32000 [==============================] - 8s 242us/step - loss: 1.1963 - val_loss: 1.8355
#
# Epoch 00015: val_loss improved from 1.89656 to 1.83546, saving model to modelGRU.h1
# Epoch 16/25
# 32000/32000 [==============================] - 7s 233us/step - loss: 1.1061 - val_loss: 1.8163
#
# Epoch 00016: val_loss improved from 1.83546 to 1.81628, saving model to modelGRU.h1
# Epoch 17/25
# 32000/32000 [==============================] - 8s 238us/step - loss: 1.0222 - val_loss: 1.7950
#
# Epoch 00017: val_loss improved from 1.81628 to 1.79503, saving model to modelGRU.h1
# Epoch 18/25
# 32000/32000 [==============================] - 8s 238us/step - loss: 0.9403 - val_loss: 1.7673
#
# Epoch 00018: val_loss improved from 1.79503 to 1.76733, saving model to modelGRU.h1
# Epoch 19/25
# 32000/32000 [==============================] - 7s 234us/step - loss: 0.8644 - val_loss: 1.7471
#
# Epoch 00019: val_loss improved from 1.76733 to 1.74712, saving model to modelGRU.h1
# Epoch 20/25
# 32000/32000 [==============================] - 7s 233us/step - loss: 0.7921 - val_loss: 1.7687
#
# Epoch 00020: val_loss did not improve from 1.74712
# Epoch 21/25
# 32000/32000 [==============================] - 8s 236us/step - loss: 0.7244 - val_loss: 1.7396
#
# Epoch 00021: val_loss improved from 1.74712 to 1.73957, saving model to modelGRU.h1
# Epoch 22/25
# 32000/32000 [==============================] - 7s 234us/step - loss: 0.6633 - val_loss: 1.7318
#
# Epoch 00022: val_loss improved from 1.73957 to 1.73179, saving model to modelGRU.h1
# Epoch 23/25
# 32000/32000 [==============================] - 8s 238us/step - loss: 0.6026 - val_loss: 1.7389
#
# Epoch 00023: val_loss did not improve from 1.73179
# Epoch 24/25
# 32000/32000 [==============================] - 8s 236us/step - loss: 0.5512 - val_loss: 1.7218
#
# Epoch 00024: val_loss improved from 1.73179 to 1.72182, saving model to modelGRU.h1
# Epoch 25/25
# 32000/32000 [==============================] - 7s 229us/step - loss: 0.4982 - val_loss: 1.7205
#
# Epoch 00025: val_loss improved from 1.72182 to 1.72046, saving model to modelGRU.h1

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train','validation'])
plt.show()

# %%
model2 = load_model('modelGRU.h1')
preds = model2.predict_classes(testX.reshape((testX.shape[0],testX.shape[1])))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
# convert predictions into text (English)
preds_text = []
for i in preds:
    temp = []
    for j in range(len(i)):
        t = get_word(i[j], eng_tokenizer)
        if j > 0:
            if (t == get_word(i[j-1], eng_tokenizer)) or (t == None):
                temp.append('')
            else:
                temp.append(t)
             
        else:
            if(t == None):
                temp.append('')
            else:
                temp.append(t)            
        
    preds_text.append(' '.join(temp))

# %%
pred_df['predicted_GRU'] = preds_text
pred_df = pred_df.rename(columns={"predicted": "predicted_LSTM"})

# %%
pred_df.head(10)
# Out:
#                       Spanish  ...            predicted_GRU
# 0    ellos son muy optimistas  ...     theyre very big
# 1               conozco a tom  ...          i know tom
# 2              puedes negarte  ...         you may fix
# 3              eso es privado  ...       thats creepy
# 4  tom saltó desde su asiento  ...    tom lit marys his
# 5  ¿jamás has vendido un auto  ...       did you ever a
# 6       ¿cuántos hijos tienes  ...  how many do  you have
# 7        no te dejaré hacerlo  ...     i wont let you  do
# 8              ¿no es hermoso  ...   isnt it beautiful
# 9          mi loro murió ayer  ...    my home died here
#
# [10 rows x 4 columns]

# %%
pred_df.tail(10)
# Out:
#                         Spanish  ...                 predicted_GRU
# 9990           quiero a su hija  ...  i want your respect shirt
# 9991     él da clases de inglés  ...         he often to study
# 9992           me quedé dormido  ...             i was asleep
# 9993     él es pobre como pocos  ...                 he is as
# 9994      ¿dónde está mi camisa  ...        wheres my brother
# 9995       ¿todo está bien aquí  ...     is everything is here
# 9996     me cansé de jugar esto  ...       im dying about this
# 9997         deshágase del arma  ...      get out the your boat
# 9998       ¿viste esta película  ...     did you pay this movie
# 9999  no tengo malicia hacia él  ...              i have no to
#
# [10 rows x 4 columns]

# %% [markdown]
# We can see that both methods have different errors, but LSTM seams to give us better results as it is a more advanced method. In following notebooks we will try to adjust LSTM to get better translations.
